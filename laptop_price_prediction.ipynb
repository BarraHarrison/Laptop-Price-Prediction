# %%
import pandas as pd

# %%
data_frame = pd.read_csv("laptop_price.csv", encoding="latin-1")

# %%
data_frame
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
data_frame.Product.value_counts()
# Out:
# Product
# XPS 13                                     30
# Inspiron 3567                              29
# 250 G6                                     21
# Legion Y520-15IKBN                         19
# Vostro 3568                                19
#                                            ..
# 15-bw007nv (A10-9620P/6GB/128GB/Radeon      1
# SmartBook 130                               1
# A541NA-GO342 (N3350/4GB/500GB/Linux)        1
# 17-X047na (i3-6006U/8GB/1TB/W10)            1
# V330-15IKB (i5-8250U/4GB/500GB/FHD/W10)     1
# Name: count, Length: 618, dtype: int64

# %%
data_frame.Company.value_counts()
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
data_frame.TypeName.value_counts()
# Out:
# TypeName
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: count, dtype: int64

# %%
data_frame.Ram.value_counts()
# Out:
# Ram
# 8GB     619
# 4GB     375
# 16GB    200
# 6GB      41
# 12GB     25
# 2GB      22
# 32GB     17
# 24GB      3
# 64GB      1
# Name: count, dtype: int64

# %%
data_frame = data_frame.drop("Product", axis=1)

# %%
data_frame
# Out:
#       laptop_ID Company            TypeName  Inches  \
# 0             1   Apple           Ultrabook    13.3
# 1             2   Apple           Ultrabook    13.3
# 2             3      HP            Notebook    15.6
# 3             4   Apple           Ultrabook    15.4
# 4             5   Apple           Ultrabook    13.3
# ...         ...     ...                 ...     ...
# 1298       1316  Lenovo  2 in 1 Convertible    14.0
# 1299       1317  Lenovo  2 in 1 Convertible    13.3
# 1300       1318  Lenovo            Notebook    14.0
# 1301       1319      HP            Notebook    15.6
# 1302       1320    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
pd.get_dummies(data_frame.Company)
# Out:
#        Acer  Apple   Asus  Chuwi   Dell  Fujitsu  Google     HP  Huawei  \
# 0     False   True  False  False  False    False   False  False   False
# 1     False   True  False  False  False    False   False  False   False
# 2     False  False  False  False  False    False   False   True   False
# 3     False   True  False  False  False    False   False  False   False
# 4     False   True  False  False  False    False   False  False   False
# ...     ...    ...    ...    ...    ...      ...     ...    ...     ...
# 1298  False  False  False  False  False    False   False  False   False
# 1299  False  False  False  False  False    False   False  False   False
# 1300  False  False  False  False  False    False   False  False   False
# 1301  False  False  False  False  False    False   False   True   False
# 1302  False  False   True  False  False    False   False  False   False
#
#          LG  Lenovo    MSI  Mediacom  Microsoft  Razer  Samsung  Toshiba  \
# ...

# %%
pd.get_dummies(data_frame.Company)
# Out:
#        Acer  Apple   Asus  Chuwi   Dell  Fujitsu  Google     HP  Huawei  \
# 0     False   True  False  False  False    False   False  False   False
# 1     False   True  False  False  False    False   False  False   False
# 2     False  False  False  False  False    False   False   True   False
# 3     False   True  False  False  False    False   False  False   False
# 4     False   True  False  False  False    False   False  False   False
# ...     ...    ...    ...    ...    ...      ...     ...    ...     ...
# 1298  False  False  False  False  False    False   False  False   False
# 1299  False  False  False  False  False    False   False  False   False
# 1300  False  False  False  False  False    False   False  False   False
# 1301  False  False  False  False  False    False   False   True   False
# 1302  False  False   True  False  False    False   False  False   False
#
#          LG  Lenovo    MSI  Mediacom  Microsoft  Razer  Samsung  Toshiba  \
# ...

# %%
data_frame = data_frame.join(pd.get_dummies(data_frame.Company))
data_frame = data_frame.drop("Company", axis=1)

# %%
data_frame
# Out:
#       laptop_ID            TypeName  Inches  \
# 0             1           Ultrabook    13.3
# 1             2           Ultrabook    13.3
# 2             3            Notebook    15.6
# 3             4           Ultrabook    15.4
# 4             5           Ultrabook    13.3
# ...         ...                 ...     ...
# 1298       1316  2 in 1 Convertible    14.0
# 1299       1317  2 in 1 Convertible    13.3
# 1300       1318            Notebook    14.0
# 1301       1319            Notebook    15.6
# 1302       1320            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %%
data_frame = data_frame.join(pd.get_dummies(data_frame.TypeName))
data_frame = data_frame.drop("TypeName", axis=1)

# %%
data_frame
# Out:
#       laptop_ID  Inches                            ScreenResolution  \
# 0             1    13.3          IPS Panel Retina Display 2560x1600
# 1             2    13.3                                    1440x900
# 2             3    15.6                           Full HD 1920x1080
# 3             4    15.4          IPS Panel Retina Display 2880x1800
# 4             5    13.3          IPS Panel Retina Display 2560x1600
# ...         ...     ...                                         ...
# 1298       1316    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299       1317    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300       1318    14.0                                    1366x768
# 1301       1319    15.6                                    1366x768
# 1302       1320    15.6                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# ...

# %%
data_frame.ScreenResolution.str.split(" ")
# Out:
# 0                [IPS, Panel, Retina, Display, 2560x1600]
# 1                                              [1440x900]
# 2                                   [Full, HD, 1920x1080]
# 3                [IPS, Panel, Retina, Display, 2880x1800]
# 4                [IPS, Panel, Retina, Display, 2560x1600]
#                               ...
# 1298    [IPS, Panel, Full, HD, /, Touchscreen, 1920x1080]
# 1299    [IPS, Panel, Quad, HD+, /, Touchscreen, 3200x1...
# 1300                                           [1366x768]
# 1301                                           [1366x768]
# 1302                                           [1366x768]
# Name: ScreenResolution, Length: 1303, dtype: object

# %%
data_frame.ScreenResolution.str.split(" ").apply(lambda x: x[-1])
# Out:
# 0       2560x1600
# 1        1440x900
# 2       1920x1080
# 3       2880x1800
# 4       2560x1600
#           ...
# 1298    1920x1080
# 1299    3200x1800
# 1300     1366x768
# 1301     1366x768
# 1302     1366x768
# Name: ScreenResolution, Length: 1303, dtype: object

# %%
data_frame["ScreenResolution"] = data_frame.ScreenResolution.str.split(" ").apply(lambda x: x[-1])
data_frame["Screen Width"] = data_frame.ScreenResolution.str.split("x").apply(lambda x: x[0])
data_frame["Screen Height"] = data_frame.ScreenResolution.str.split("x").apply(lambda x: x[1])

# %%
data_frame
# Out:
#       laptop_ID  Inches ScreenResolution  \
# 0             1    13.3        2560x1600
# 1             2    13.3         1440x900
# 2             3    15.6        1920x1080
# 3             4    15.4        2880x1800
# 4             5    13.3        2560x1600
# ...         ...     ...              ...
# 1298       1316    14.0        1920x1080
# 1299       1317    13.3        3200x1800
# 1300       1318    14.0         1366x768
# 1301       1319    15.6         1366x768
# 1302       1320    15.6         1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...

# %%
data_frame = data_frame.drop("ScreenResolution", axis=1)

# %%
data_frame
# Out:
#       laptop_ID  Inches                                   Cpu   Ram  \
# 0             1    13.3                  Intel Core i5 2.3GHz   8GB
# 1             2    13.3                  Intel Core i5 1.8GHz   8GB
# 2             3    15.6            Intel Core i5 7200U 2.5GHz   8GB
# 3             4    15.4                  Intel Core i7 2.7GHz  16GB
# 4             5    13.3                  Intel Core i5 3.1GHz   8GB
# ...         ...     ...                                   ...   ...
# 1298       1316    14.0            Intel Core i7 6500U 2.5GHz   4GB
# 1299       1317    13.3            Intel Core i7 6500U 2.5GHz  16GB
# 1300       1318    14.0  Intel Celeron Dual Core N3050 1.6GHz   2GB
# 1301       1319    15.6            Intel Core i7 6500U 2.5GHz   6GB
# 1302       1320    15.6  Intel Celeron Dual Core N3050 1.6GHz   4GB
#
#                    Memory                           Gpu       OpSys  Weight  \
# ...

# %%
data_frame.Cpu.str.split(" ").apply(lambda x: x[0])
# Out:
# 0       Intel
# 1       Intel
# 2       Intel
# 3       Intel
# 4       Intel
#         ...
# 1298    Intel
# 1299    Intel
# 1300    Intel
# 1301    Intel
# 1302    Intel
# Name: Cpu, Length: 1303, dtype: object

# %%
data_frame.Cpu.str.split(" ").apply(lambda x: x[1])
# Out:
# 0          Core
# 1          Core
# 2          Core
# 3          Core
# 4          Core
#          ...
# 1298       Core
# 1299       Core
# 1300    Celeron
# 1301       Core
# 1302    Celeron
# Name: Cpu, Length: 1303, dtype: object

# %%
data_frame.Cpu.str.split(" ").apply(lambda x: x[2])
# Out:
# 0         i5
# 1         i5
# 2         i5
# 3         i7
# 4         i5
#         ...
# 1298      i7
# 1299      i7
# 1300    Dual
# 1301      i7
# 1302    Dual
# Name: Cpu, Length: 1303, dtype: object

# %%
data_frame.Cpu.str.split(" ").apply(lambda x: x[3])
# Out:
# 0       2.3GHz
# 1       1.8GHz
# 2        7200U
# 3       2.7GHz
# 4       3.1GHz
#          ...
# 1298     6500U
# 1299     6500U
# 1300      Core
# 1301     6500U
# 1302      Core
# Name: Cpu, Length: 1303, dtype: object

# %%
data_frame.Cpu.str.split(" ").apply(lambda x: x[-1])
# Out:
# 0       2.3GHz
# 1       1.8GHz
# 2       2.5GHz
# 3       2.7GHz
# 4       3.1GHz
#          ...
# 1298    2.5GHz
# 1299    2.5GHz
# 1300    1.6GHz
# 1301    2.5GHz
# 1302    1.6GHz
# Name: Cpu, Length: 1303, dtype: object

# %%
data_frame["CPU Brand"] = data_frame.Cpu.str.split(" ").apply(lambda x: x[0])
data_frame["CPU Frequency"] = data_frame.Cpu.str.split(" ").apply(lambda x: x[-1])

# %%
data_frame.drop("Cpu", axis=1)
# Out:
#       laptop_ID  Inches   Ram               Memory  \
# 0             1    13.3   8GB            128GB SSD
# 1             2    13.3   8GB  128GB Flash Storage
# 2             3    15.6   8GB            256GB SSD
# 3             4    15.4  16GB            512GB SSD
# 4             5    13.3   8GB            256GB SSD
# ...         ...     ...   ...                  ...
# 1298       1316    14.0   4GB            128GB SSD
# 1299       1317    13.3  16GB            512GB SSD
# 1300       1318    14.0   2GB   64GB Flash Storage
# 1301       1319    15.6   6GB              1TB HDD
# 1302       1320    15.6   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros   Acer  \
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69  False
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94  False
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00  False
# ...

# %%
data_frame.drop("Cpu", axis=1)
# Out:
#       laptop_ID  Inches   Ram               Memory  \
# 0             1    13.3   8GB            128GB SSD
# 1             2    13.3   8GB  128GB Flash Storage
# 2             3    15.6   8GB            256GB SSD
# 3             4    15.4  16GB            512GB SSD
# 4             5    13.3   8GB            256GB SSD
# ...         ...     ...   ...                  ...
# 1298       1316    14.0   4GB            128GB SSD
# 1299       1317    13.3  16GB            512GB SSD
# 1300       1318    14.0   2GB   64GB Flash Storage
# 1301       1319    15.6   6GB              1TB HDD
# 1302       1320    15.6   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros   Acer  \
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69  False
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94  False
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00  False
# ...

# %%
data_frame["CPU Frequency"] = data_frame["CPU Frequency"].str[:-3]

# %%
data_frame = data_frame.drop("Cpu", axis=1)

# %%
data_frame
# Out:
#       laptop_ID  Inches   Ram               Memory  \
# 0             1    13.3   8GB            128GB SSD
# 1             2    13.3   8GB  128GB Flash Storage
# 2             3    15.6   8GB            256GB SSD
# 3             4    15.4  16GB            512GB SSD
# 4             5    13.3   8GB            256GB SSD
# ...         ...     ...   ...                  ...
# 1298       1316    14.0   4GB            128GB SSD
# 1299       1317    13.3  16GB            512GB SSD
# 1300       1318    14.0   2GB   64GB Flash Storage
# 1301       1319    15.6   6GB              1TB HDD
# 1302       1320    15.6   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros   Acer  \
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69  False
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94  False
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00  False
# ...

# %%
data_frame["Ram"] = data_frame["Ram"].str[:-2]

# %%
data_frame
# Out:
#       laptop_ID  Inches Ram               Memory  \
# 0             1    13.3   8            128GB SSD
# 1             2    13.3   8  128GB Flash Storage
# 2             3    15.6   8            256GB SSD
# 3             4    15.4  16            512GB SSD
# 4             5    13.3   8            256GB SSD
# ...         ...     ...  ..                  ...
# 1298       1316    14.0   4            128GB SSD
# 1299       1317    13.3  16            512GB SSD
# 1300       1318    14.0   2   64GB Flash Storage
# 1301       1319    15.6   6              1TB HDD
# 1302       1320    15.6   4            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros   Acer  \
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69  False
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94  False
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00  False
# ...

# %%
data_frame["Ram"].astype("int")
# Out:
# 0        8
# 1        8
# 2        8
# 3       16
# 4        8
#         ..
# 1298     4
# 1299    16
# 1300     2
# 1301     6
# 1302     4
# Name: Ram, Length: 1303, dtype: int64

# %%
data_frame["Ram"] = data_frame["Ram"].astype("int")

# %%
data_frame["CPU Frequency"] = data_frame["CPU Frequency"].astype("float")

# %%
data_frame
# Out:
#       laptop_ID  Inches  Ram               Memory  \
# 0             1    13.3    8            128GB SSD
# 1             2    13.3    8  128GB Flash Storage
# 2             3    15.6    8            256GB SSD
# 3             4    15.4   16            512GB SSD
# 4             5    13.3    8            256GB SSD
# ...         ...     ...  ...                  ...
# 1298       1316    14.0    4            128GB SSD
# 1299       1317    13.3   16            512GB SSD
# 1300       1318    14.0    2   64GB Flash Storage
# 1301       1319    15.6    6              1TB HDD
# 1302       1320    15.6    4            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros   Acer  \
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69  False
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94  False
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00  False
# ...

# %%
data_frame["Screen Width"] = data_frame["Screen Width"].astype("int")
data_frame["Screen Height"] = data_frame["Screen Height"].astype("int")

# %%
data_frame.hist()
# Out:
# array([[<Axes: title={'center': 'laptop_ID'}>,
#         <Axes: title={'center': 'Inches'}>,
#         <Axes: title={'center': 'Ram'}>],
#        [<Axes: title={'center': 'Price_euros'}>,
#         <Axes: title={'center': 'Screen Width'}>,
#         <Axes: title={'center': 'Screen Height'}>],
#        [<Axes: title={'center': 'CPU Frequency'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
data_frame
# Out:
#       laptop_ID  Inches  Ram               Memory  \
# 0             1    13.3    8            128GB SSD
# 1             2    13.3    8  128GB Flash Storage
# 2             3    15.6    8            256GB SSD
# 3             4    15.4   16            512GB SSD
# 4             5    13.3    8            256GB SSD
# ...         ...     ...  ...                  ...
# 1298       1316    14.0    4            128GB SSD
# 1299       1317    13.3   16            512GB SSD
# 1300       1318    14.0    2   64GB Flash Storage
# 1301       1319    15.6    6              1TB HDD
# 1302       1320    15.6    4            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros   Acer  \
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69  False
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94  False
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00  False
# ...

# %%
data_frame["Memory Amount"] = data_frame.Memory.str.split(" ").apply(lambda x: x[0])
data_frame["Memory Type"] = data_frame.Memory.str.split(" ").apply(lambda x: x[1])

# %%
data_frame["Memory Type"].value_counts()
# Out:
# Memory Type
# SSD       843
# HDD       375
# Flash      75
# Hybrid     10
# Name: count, dtype: int64

# %%
data_frame["Memory Amount"].value_counts()
# Out:
# Memory Amount
# 256GB    508
# 1TB      240
# 128GB    177
# 512GB    140
# 500GB    132
# 32GB      45
# 64GB      17
# 2TB       16
# 1.0TB     10
# 16GB      10
# 180GB      5
# 240GB      1
# 8GB        1
# 508GB      1
# Name: count, dtype: int64

# %%
def turn_memory_into_MB(value):
    if "GB" in value:
        return float(value[:value.find("GB")]) * 1000
    elif "TB" in value:
        return float(value[:value.find("TB")]) * 1000000

# %%
data_frame["Memory Amount"].apply(turn_memory_into_MB)
# Out:
# 0        128000.0
# 1        128000.0
# 2        256000.0
# 3        512000.0
# 4        256000.0
#           ...
# 1298     128000.0
# 1299     512000.0
# 1300      64000.0
# 1301    1000000.0
# 1302     500000.0
# Name: Memory Amount, Length: 1303, dtype: float64

# %%
data_frame["Memory Amount"] = data_frame["Memory Amount"].apply(turn_memory_into_MB)

# %%
data_frame
# Out:
#       laptop_ID  Inches  Ram               Memory  \
# 0             1    13.3    8            128GB SSD
# 1             2    13.3    8  128GB Flash Storage
# 2             3    15.6    8            256GB SSD
# 3             4    15.4   16            512GB SSD
# 4             5    13.3    8            256GB SSD
# ...         ...     ...  ...                  ...
# 1298       1316    14.0    4            128GB SSD
# 1299       1317    13.3   16            512GB SSD
# 1300       1318    14.0    2   64GB Flash Storage
# 1301       1319    15.6    6              1TB HDD
# 1302       1320    15.6    4            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros   Acer  \
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69  False
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94  False
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00  False
# ...

# %%
data_frame = data_frame.drop("Memory", axis=1)

# %%
data_frame
# Out:
#       laptop_ID  Inches  Ram                           Gpu       OpSys  \
# 0             1    13.3    8  Intel Iris Plus Graphics 640       macOS
# 1             2    13.3    8        Intel HD Graphics 6000       macOS
# 2             3    15.6    8         Intel HD Graphics 620       No OS
# 3             4    15.4   16            AMD Radeon Pro 455       macOS
# 4             5    13.3    8  Intel Iris Plus Graphics 650       macOS
# ...         ...     ...  ...                           ...         ...
# 1298       1316    14.0    4         Intel HD Graphics 520  Windows 10
# 1299       1317    13.3   16         Intel HD Graphics 520  Windows 10
# 1300       1318    14.0    2             Intel HD Graphics  Windows 10
# 1301       1319    15.6    6            AMD Radeon R5 M330  Windows 10
# 1302       1320    15.6    4             Intel HD Graphics  Windows 10
#
#       Weight  Price_euros   Acer  Apple   Asus  ...  Netbook  Notebook  \
# ...

# %%
data_frame["Weight"].value_counts()
# Out:
# Weight
# 2.2kg     121
# 2.1kg      58
# 2.4kg      44
# 2.3kg      41
# 2.5kg      38
#          ...
# 3.25kg      1
# 4.7kg       1
# 1.55kg      1
# 1.18kg      1
# 4.0kg       1
# Name: count, Length: 179, dtype: int64

# %%
data_frame["Weight"] = data_frame["Weight"].str[:-2]

# %%
data_frame
# Out:
#       laptop_ID  Inches  Ram                           Gpu       OpSys Weight  \
# 0             1    13.3    8  Intel Iris Plus Graphics 640       macOS   1.37
# 1             2    13.3    8        Intel HD Graphics 6000       macOS   1.34
# 2             3    15.6    8         Intel HD Graphics 620       No OS   1.86
# 3             4    15.4   16            AMD Radeon Pro 455       macOS   1.83
# 4             5    13.3    8  Intel Iris Plus Graphics 650       macOS   1.37
# ...         ...     ...  ...                           ...         ...    ...
# 1298       1316    14.0    4         Intel HD Graphics 520  Windows 10    1.8
# 1299       1317    13.3   16         Intel HD Graphics 520  Windows 10    1.3
# 1300       1318    14.0    2             Intel HD Graphics  Windows 10    1.5
# 1301       1319    15.6    6            AMD Radeon R5 M330  Windows 10   2.19
# 1302       1320    15.6    4             Intel HD Graphics  Windows 10    2.2
#
# ...

# %%
data_frame["Weight"] = data_frame["Weight"].astype("float")

# %%
data_frame
# Out:
#       laptop_ID  Inches  Ram                           Gpu       OpSys  \
# 0             1    13.3    8  Intel Iris Plus Graphics 640       macOS
# 1             2    13.3    8        Intel HD Graphics 6000       macOS
# 2             3    15.6    8         Intel HD Graphics 620       No OS
# 3             4    15.4   16            AMD Radeon Pro 455       macOS
# 4             5    13.3    8  Intel Iris Plus Graphics 650       macOS
# ...         ...     ...  ...                           ...         ...
# 1298       1316    14.0    4         Intel HD Graphics 520  Windows 10
# 1299       1317    13.3   16         Intel HD Graphics 520  Windows 10
# 1300       1318    14.0    2             Intel HD Graphics  Windows 10
# 1301       1319    15.6    6            AMD Radeon R5 M330  Windows 10
# 1302       1320    15.6    4             Intel HD Graphics  Windows 10
#
#       Weight  Price_euros   Acer  Apple   Asus  ...  Netbook  Notebook  \
# ...

# %%
data_frame["GPU Brand"] = data_frame.Gpu.str.split(" ").apply(lambda x: x[0])

# %%
data_frame
# Out:
#       laptop_ID  Inches  Ram                           Gpu       OpSys  \
# 0             1    13.3    8  Intel Iris Plus Graphics 640       macOS
# 1             2    13.3    8        Intel HD Graphics 6000       macOS
# 2             3    15.6    8         Intel HD Graphics 620       No OS
# 3             4    15.4   16            AMD Radeon Pro 455       macOS
# 4             5    13.3    8  Intel Iris Plus Graphics 650       macOS
# ...         ...     ...  ...                           ...         ...
# 1298       1316    14.0    4         Intel HD Graphics 520  Windows 10
# 1299       1317    13.3   16         Intel HD Graphics 520  Windows 10
# 1300       1318    14.0    2             Intel HD Graphics  Windows 10
# 1301       1319    15.6    6            AMD Radeon R5 M330  Windows 10
# 1302       1320    15.6    4             Intel HD Graphics  Windows 10
#
#       Weight  Price_euros   Acer  Apple   Asus  ...  Notebook  Ultrabook  \
# ...

# %%
data_frame = data_frame.drop("Gpu", axis=1)

# %%
data_frame
# Out:
#       laptop_ID  Inches  Ram       OpSys  Weight  Price_euros   Acer  Apple  \
# 0             1    13.3    8       macOS    1.37      1339.69  False   True
# 1             2    13.3    8       macOS    1.34       898.94  False   True
# 2             3    15.6    8       No OS    1.86       575.00  False  False
# 3             4    15.4   16       macOS    1.83      2537.45  False   True
# 4             5    13.3    8       macOS    1.37      1803.60  False   True
# ...         ...     ...  ...         ...     ...          ...    ...    ...
# 1298       1316    14.0    4  Windows 10    1.80       638.00  False  False
# 1299       1317    13.3   16  Windows 10    1.30      1499.00  False  False
# 1300       1318    14.0    2  Windows 10    1.50       229.00  False  False
# 1301       1319    15.6    6  Windows 10    2.19       764.00  False  False
# 1302       1320    15.6    4  Windows 10    2.20       369.00  False  False
#
# ...

# %%
data_frame.join(pd.get_dummies(data_frame.OpSys))
# Out:
#       laptop_ID  Inches  Ram       OpSys  Weight  Price_euros   Acer  Apple  \
# 0             1    13.3    8       macOS    1.37      1339.69  False   True
# 1             2    13.3    8       macOS    1.34       898.94  False   True
# 2             3    15.6    8       No OS    1.86       575.00  False  False
# 3             4    15.4   16       macOS    1.83      2537.45  False   True
# 4             5    13.3    8       macOS    1.37      1803.60  False   True
# ...         ...     ...  ...         ...     ...          ...    ...    ...
# 1298       1316    14.0    4  Windows 10    1.80       638.00  False  False
# 1299       1317    13.3   16  Windows 10    1.30      1499.00  False  False
# 1300       1318    14.0    2  Windows 10    1.50       229.00  False  False
# 1301       1319    15.6    6  Windows 10    2.19       764.00  False  False
# 1302       1320    15.6    4  Windows 10    2.20       369.00  False  False
#
# ...

# %%
data_frame = data_frame.join(pd.get_dummies(data_frame.OpSys))
data_frame = data_frame.drop("OpSys", axis=1)

# %%
data_frame
# Out:
#       laptop_ID  Inches  Ram  Weight  Price_euros   Acer  Apple   Asus  Chuwi  \
# 0             1    13.3    8    1.37      1339.69  False   True  False  False
# 1             2    13.3    8    1.34       898.94  False   True  False  False
# 2             3    15.6    8    1.86       575.00  False  False  False  False
# 3             4    15.4   16    1.83      2537.45  False   True  False  False
# 4             5    13.3    8    1.37      1803.60  False   True  False  False
# ...         ...     ...  ...     ...          ...    ...    ...    ...    ...
# 1298       1316    14.0    4    1.80       638.00  False  False  False  False
# 1299       1317    13.3   16    1.30      1499.00  False  False  False  False
# 1300       1318    14.0    2    1.50       229.00  False  False  False  False
# 1301       1319    15.6    6    2.19       764.00  False  False  False  False
# 1302       1320    15.6    4    2.20       369.00  False  False   True  False
#
# ...

# %%
data_frame["CPU Brand"]
# Out:
# 0       Intel
# 1       Intel
# 2       Intel
# 3       Intel
# 4       Intel
#         ...
# 1298    Intel
# 1299    Intel
# 1300    Intel
# 1301    Intel
# 1302    Intel
# Name: CPU Brand, Length: 1303, dtype: object

# %%
data_frame["GPU Brand"]
# Out:
# 0       Intel
# 1       Intel
# 2       Intel
# 3         AMD
# 4       Intel
#         ...
# 1298    Intel
# 1299    Intel
# 1300    Intel
# 1301      AMD
# 1302    Intel
# Name: GPU Brand, Length: 1303, dtype: object

# %%
cpu_categories = pd.get_dummies(data_frame["CPU Brand"])
cpu_categories.columns = [col + "_CPU" for col in cpu_categories.columns]

data_frame = data_frame.join(cpu_categories)
data_frame = data_frame.drop("CPU Brand", axis=1)

# %%
data_frame
# Out:
#       laptop_ID  Inches  Ram  Weight  Price_euros   Acer  Apple   Asus  Chuwi  \
# 0             1    13.3    8    1.37      1339.69  False   True  False  False
# 1             2    13.3    8    1.34       898.94  False   True  False  False
# 2             3    15.6    8    1.86       575.00  False  False  False  False
# 3             4    15.4   16    1.83      2537.45  False   True  False  False
# 4             5    13.3    8    1.37      1803.60  False   True  False  False
# ...         ...     ...  ...     ...          ...    ...    ...    ...    ...
# 1298       1316    14.0    4    1.80       638.00  False  False  False  False
# 1299       1317    13.3   16    1.30      1499.00  False  False  False  False
# 1300       1318    14.0    2    1.50       229.00  False  False  False  False
# 1301       1319    15.6    6    2.19       764.00  False  False  False  False
# 1302       1320    15.6    4    2.20       369.00  False  False   True  False
#
# ...

# %%
gpu_categories = pd.get_dummies(data_frame["GPU Brand"])
gpu_categories.columns = [col + "_GPU" for col in gpu_categories.columns]

data_frame = data_frame.join(gpu_categories)
data_frame = data_frame.drop("GPU Brand", axis=1)

# %%
data_frame
# Out:
#       laptop_ID  Inches  Ram  Weight  Price_euros   Acer  Apple   Asus  Chuwi  \
# 0             1    13.3    8    1.37      1339.69  False   True  False  False
# 1             2    13.3    8    1.34       898.94  False   True  False  False
# 2             3    15.6    8    1.86       575.00  False  False  False  False
# 3             4    15.4   16    1.83      2537.45  False   True  False  False
# 4             5    13.3    8    1.37      1803.60  False   True  False  False
# ...         ...     ...  ...     ...          ...    ...    ...    ...    ...
# 1298       1316    14.0    4    1.80       638.00  False  False  False  False
# 1299       1317    13.3   16    1.30      1499.00  False  False  False  False
# 1300       1318    14.0    2    1.50       229.00  False  False  False  False
# 1301       1319    15.6    6    2.19       764.00  False  False  False  False
# 1302       1320    15.6    4    2.20       369.00  False  False   True  False
#
# ...

# %%
data_frame.columns
# Out:
# Index(['laptop_ID', 'Inches', 'Ram', 'Weight', 'Price_euros', 'Acer', 'Apple',
#        'Asus', 'Chuwi', 'Dell', 'Fujitsu', 'Google', 'HP', 'Huawei', 'LG',
#        'Lenovo', 'MSI', 'Mediacom', 'Microsoft', 'Razer', 'Samsung', 'Toshiba',
#        'Vero', 'Xiaomi', '2 in 1 Convertible', 'Gaming', 'Netbook', 'Notebook',
#        'Ultrabook', 'Workstation', 'Screen Width', 'Screen Height',
#        'CPU Frequency', 'Memory Amount', 'Memory Type', 'Android', 'Chrome OS',
#        'Linux', 'Mac OS X', 'No OS', 'Windows 10', 'Windows 10 S', 'Windows 7',
#        'macOS', 'AMD_CPU', 'Intel_CPU', 'Samsung_CPU', 'AMD_GPU', 'ARM_GPU',
#        'Intel_GPU', 'Nvidia_GPU'],
#       dtype='object')

# %%
print(data_frame.dtypes)
# Out:
# laptop_ID               int64
# Inches                float64
# Ram                     int64
# Weight                float64
# Price_euros           float64
# Acer                     bool
# Apple                    bool
# Asus                     bool
# Chuwi                    bool
# Dell                     bool
# Fujitsu                  bool
# Google                   bool
# HP                       bool
# Huawei                   bool
# LG                       bool
# Lenovo                   bool
# MSI                      bool
# Mediacom                 bool
# Microsoft                bool
# Razer                    bool
# Samsung                  bool
# Toshiba                  bool
# Vero                     bool
# Xiaomi                   bool
# 2 in 1 Convertible       bool
# Gaming                   bool
# Netbook                  bool
# Notebook                 bool
# Ultrabook                bool
# Workstation              bool
# Screen Width            int64
# ...

# %%
data_frame.corr(numeric_only=True)
# Out:
#                     laptop_ID    Inches       Ram    Weight  Price_euros  \
# laptop_ID            1.000000 -0.087796 -0.028607 -0.011798     0.067830
# Inches              -0.087796  1.000000  0.237993  0.827631     0.068197
# Ram                 -0.028607  0.237993  1.000000  0.383874     0.743007
# Weight              -0.011798  0.827631  0.383874  1.000000     0.210370
# Price_euros          0.067830  0.068197  0.743007  0.210370     1.000000
# Acer                -0.057721  0.009435 -0.138432  0.056444    -0.208349
# Apple               -0.119585 -0.158850  0.023950 -0.138191     0.080688
# Asus                -0.044252  0.112766  0.088634  0.101332    -0.010376
# Chuwi               -0.043348 -0.017426 -0.035117 -0.022536    -0.055646
# Dell                -0.013628  0.045288  0.082241  0.088465     0.048509
# Fujitsu              0.009268  0.019637 -0.016214  0.014053    -0.027135
# Google              -0.012039 -0.091551  0.021591 -0.067790     0.038086
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(18,15))
sns.heatmap(data_frame.corr(numeric_only=True), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
target_correlations = data_frame.corr(numeric_only=True)["Price_euros"].apply(abs).sort_values()

# %%
target_correlations
# Out:
# Xiaomi                0.000776
# Asus                  0.010376
# Mac OS X              0.015656
# Huawei                0.016851
# Windows 10 S          0.018312
# ARM_GPU               0.018431
# Samsung_CPU           0.018431
# Fujitsu               0.027135
# Lenovo                0.029007
# Samsung               0.034584
# Google                0.038086
# Android               0.038700
# Toshiba               0.040339
# HP                    0.041291
# Microsoft             0.047562
# Dell                  0.048509
# Chuwi                 0.055646
# LG                    0.067053
# laptop_ID             0.067830
# Inches                0.068197
# Vero                  0.071972
# 2 in 1 Convertible    0.072675
# Apple                 0.080688
# Mediacom              0.087161
# macOS                 0.089928
# Netbook               0.097572
# Chrome OS             0.118684
# Memory Amount         0.122365
# Windows 10            0.137048
# Windows 7             0.152381
# ...

# %%
selected_features = target_correlations[-20:].index

# %%
selected_features
# Out:
# Index(['Linux', 'No OS', 'MSI', 'AMD_CPU', 'Intel_CPU', 'Intel_GPU', 'AMD_GPU',
#        'Acer', 'Weight', 'Razer', 'Workstation', 'Ultrabook', 'Nvidia_GPU',
#        'Gaming', 'CPU Frequency', 'Notebook', 'Screen Height', 'Screen Width',
#        'Ram', 'Price_euros'],
#       dtype='object')

# %%
selected_features = list(selected_features)

# %%
selected_features
# Out:
# ['Linux',
#  'No OS',
#  'MSI',
#  'AMD_CPU',
#  'Intel_CPU',
#  'Intel_GPU',
#  'AMD_GPU',
#  'Acer',
#  'Weight',
#  'Razer',
#  'Workstation',
#  'Ultrabook',
#  'Nvidia_GPU',
#  'Gaming',
#  'CPU Frequency',
#  'Notebook',
#  'Screen Height',
#  'Screen Width',
#  'Ram',
#  'Price_euros']

# %%
limited_data_frame = data_frame[selected_features]

# %%
limited_data_frame
# Out:
#       Linux  No OS    MSI  AMD_CPU  Intel_CPU  Intel_GPU  AMD_GPU   Acer  \
# 0     False  False  False    False       True       True    False  False
# 1     False  False  False    False       True       True    False  False
# 2     False   True  False    False       True       True    False  False
# 3     False  False  False    False       True      False     True  False
# 4     False  False  False    False       True       True    False  False
# ...     ...    ...    ...      ...        ...        ...      ...    ...
# 1298  False  False  False    False       True       True    False  False
# 1299  False  False  False    False       True       True    False  False
# 1300  False  False  False    False       True       True    False  False
# 1301  False  False  False    False       True      False     True  False
# 1302  False  False  False    False       True       True    False  False
#
#       Weight  Razer  Workstation  Ultrabook  Nvidia_GPU  Gaming  \
# ...

# %%
plt.figure(figsize=(18,15))
sns.heatmap(limited_data_frame.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

x, y = limited_data_frame.drop("Price_euros", axis=1), limited_data_frame["Price_euros"]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.15)

scaler = StandardScaler()

x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
forest = RandomForestRegressor()

forest.fit(x_train_scaled, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test_scaled, y_test)
# Out:
# 0.8080853428068998

# %%
y_prediction = forest.predict(x_test_scaled)

# %%
plt.figure(figsize=(12,8))
plt.scatter(y_prediction, y_test)
plt.plot(range(0, 6000), range(0, 6000), c="red")

# %%
x_test.iloc[0]
# Out:
# Linux            False
# No OS            False
# MSI              False
# AMD_CPU          False
# Intel_CPU         True
# Intel_GPU        False
# AMD_GPU          False
# Acer             False
# Weight             1.7
# Razer            False
# Workstation      False
# Ultrabook        False
# Nvidia_GPU        True
# Gaming           False
# CPU Frequency      1.8
# Notebook          True
# Screen Height     1080
# Screen Width      1920
# Ram                  8
# Name: 119, dtype: object

# %%
x_test.iloc[1]
# Out:
# Linux            False
# No OS            False
# MSI               True
# AMD_CPU          False
# Intel_CPU         True
# Intel_GPU        False
# AMD_GPU          False
# Acer             False
# Weight             2.2
# Razer            False
# Workstation      False
# Ultrabook        False
# Nvidia_GPU        True
# Gaming            True
# CPU Frequency      2.7
# Notebook         False
# Screen Height     1080
# Screen Width      1920
# Ram                  8
# Name: 1169, dtype: object

# %%
x_test = x_test.astype(int)

# %%
x_test.iloc[0]
# Out:
# Linux               0
# No OS               0
# MSI                 0
# AMD_CPU             0
# Intel_CPU           1
# Intel_GPU           0
# AMD_GPU             0
# Acer                0
# Weight              1
# Razer               0
# Workstation         0
# Ultrabook           0
# Nvidia_GPU          1
# Gaming              0
# CPU Frequency       1
# Notebook            1
# Screen Height    1080
# Screen Width     1920
# Ram                 8
# Name: 119, dtype: int64

# %%
x_new_scaled = scaler.transform([x_test.iloc[0]])
# Out:
# /Users/barraharrison/Desktop/2025 Coding/Laptop-Price-Prediction/venv/lib/python3.9/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
forest.predict(x_new_scaled)
# Out:
# array([1212.53905238])

# %%
y_test.iloc[0]
# Out:
# np.float64(1118.0)
